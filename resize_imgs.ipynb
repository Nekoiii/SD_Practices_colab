# %% [markdown]
# <a href="https://colab.research.google.com/github/Nekoiii/ML_Practices_colab/blob/main/resize_imgs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import os
import shutil


def resize_imgs(input_folder,output_folder,target_height,target_width):

  if os.path.exists(output_folder):
    shutil.rmtree(output_folder)
  os.makedirs(output_folder)
  
  for filename in os.listdir(input_folder):
    if filename.endswith(('.jpg', '.jpeg', '.png')): 
      img_path = os.path.join(input_folder, filename)
      output_path = os.path.join(output_folder, filename)
      
      img = cv2.imread(img_path)
      height, width = img.shape[:2]

      if height < width:
        scale = target_height / height
      else:
        scale = target_width / width

      if scale < 1:
          img = cv2.resize(img, None, fx=scale, fy=scale, interpolation=cv2.INTER_AREA)
      elif scale > 1:
          img = cv2.resize(img, None, fx=scale, fy=scale, interpolation=cv2.INTER_CUBIC)
      
      new_height, new_width = img.shape[:2]
      start_x = (new_width - target_width) // 2
      start_y = (new_height - target_height) // 4
      end_x = start_x + target_width
      end_y = start_y + target_height
      cropped_img = img[start_y:end_y, start_x:end_x]
      
      cv2.imwrite(output_path, cropped_img)
      print(f"Resized and cropped image: {filename}")
  
  print("Image resizing completed.")


target_height=512
target_width=512
input_folder='/content/drive/MyDrive/ML_Practices/Lora_test_1/instance_imgs_2'
output_folder='/content/drive/MyDrive/ML_Practices/Lora_test_1/resized_sample_data_3'
resize_imgs(input_folder,output_folder,target_height,target_width)
# Out:
# Resized and cropped image: 17038_color.png
# Resized and cropped image: 17023_color.png
# Resized and cropped image: 16931_color.png
# Resized and cropped image: 16918_color.png
# Resized and cropped image: 16765_color.png
# Resized and cropped image: 16630_color.png
# Resized and cropped image: 16600_color.png
# Resized and cropped image: 16586_color.png
# Resized and cropped image: 16579_color.png
# Resized and cropped image: 16573_color.png
# Resized and cropped image: 16538_color.png
# Resized and cropped image: 16277_color.png
# Resized and cropped image: 16515_color.png
# Resized and cropped image: 15769_color.png
# Resized and cropped image: 15762_color.png
# Resized and cropped image: 15684_color.png
# Resized and cropped image: 截屏2023-06-03 19.18.00.png
# Resized and cropped image: 截屏2023-06-03 19.18.06.png
# Resized and cropped image: 截屏2023-06-03 19.18.15.png
# Resized and cropped image: 15412_color.png
# Resized and cropped image: 15461_color.png
# Resized and cropped image: 15399_color.png
# Resized and cropped image: 13808_color.png
# Resized and cropped image: 13632_color.png
# Resized and cropped image: 13664_color.png
# Resized and cropped image: 13618_color.png
# Resized and cropped image: 13550_color.png
# Resized and cropped image: 13553_color.png
# Resized and cropped image: 13542_color.png
# Resized and cropped image: 截屏2023-06-03 19.20.15.png
# Resized and cropped image: 截屏2023-06-03 19.20.20.png
# Resized and cropped image: 截屏2023-06-03 19.20.24.png
# Resized and cropped image: 截屏2023-06-03 19.20.29.png
# Resized and cropped image: 13194_color.png
# Resized and cropped image: 截屏2023-06-03 19.20.52.png
# Resized and cropped image: 截屏2023-06-03 19.20.56.png
# Resized and cropped image: 12981_color.png
# Resized and cropped image: 12929_color.png
# Resized and cropped image: 12836_color.png
# Resized and cropped image: 12737_color.png
# Resized and cropped image: 12640_color.png
# Resized and cropped image: 12464_color.png
# Resized and cropped image: 12451_color.png
# Resized and cropped image: 截屏2023-06-03 19.21.34.png
# Resized and cropped image: 12412_color.png
# Resized and cropped image: 12386_color.png
# Resized and cropped image: 12311_color.png
# Resized and cropped image: 12118_color.png
# Resized and cropped image: 11971_color.png
# Resized and cropped image: 截屏2023-06-03 19.22.28.png
# Resized and cropped image: 11933_color.png
# Resized and cropped image: 11955_color.png
# Resized and cropped image: 11835_color.png
# Resized and cropped image: 11822_color.png
# Resized and cropped image: 11583_color.png
# Resized and cropped image: 11569_color.png
# Resized and cropped image: 截屏2023-06-03 19.23.23.png
# Resized and cropped image: 11548_color.png
# Resized and cropped image: 11540_color.png
# Resized and cropped image: 11516_color.png
# Resized and cropped image: 11414_color.png
# Resized and cropped image: 11404_color.png
# Resized and cropped image: 11369_color.png
# Resized and cropped image: 截屏2023-06-03 19.23.43.png
# Resized and cropped image: 11304_color.png
# Resized and cropped image: 截屏2023-06-03 19.23.47.png
# Resized and cropped image: 截屏2023-06-03 19.23.53.png
# Resized and cropped image: 截屏2023-06-03 19.24.30.png
# Resized and cropped image: 截屏2023-06-03 19.24.34.png
# Resized and cropped image: 截屏2023-06-03 19.24.37.png
# Resized and cropped image: 11030_color.png
# Resized and cropped image: 截屏2023-06-03 19.24.51.png
# Resized and cropped image: 10870_color.png
# Resized and cropped image: 截屏2023-06-03 19.24.58.png
# Resized and cropped image: 截屏2023-06-03 19.25.05.png
# Resized and cropped image: 10825_color.png
# Resized and cropped image: 10805_color.png
# Resized and cropped image: 截屏2023-06-03 19.25.49.png
# Resized and cropped image: 10264_color.png
# Resized and cropped image: 10342_color.png
# Resized and cropped image: 10425_color.png
# Resized and cropped image: 截屏2023-06-03 19.25.54.png
# Resized and cropped image: 9973_color.png
# Resized and cropped image: 9696_color.png
# Resized and cropped image: 9543_color.png
# Resized and cropped image: 9553_color.png
# Resized and cropped image: 9522_color.png
# Resized and cropped image: 9471_color.png
# Resized and cropped image: 9289_color.png
# Resized and cropped image: 8484_color.png
# Resized and cropped image: 截屏2023-06-03 19.26.51.png
# Resized and cropped image: 8465_color.png
# Resized and cropped image: 8445_color.png
# Resized and cropped image: 8390_color.png
# Resized and cropped image: 8377_color.png
# Resized and cropped image: 8299_color.png
# Resized and cropped image: 8241_color.png
# Resized and cropped image: 8205_color.png
# Resized and cropped image: 8194_color.png
# Resized and cropped image: 截屏2023-06-03 19.27.11.png
# Resized and cropped image: 7913_color.png
# Resized and cropped image: 7891_color.png
# Resized and cropped image: 11438_color.png
# Resized and cropped image: 7863_color.png
# Resized and cropped image: 11464_color.png
# Resized and cropped image: 7852_color.png
# Resized and cropped image: 11507_color.png
# Resized and cropped image: 7789_color.png
# Resized and cropped image: 截屏2023-06-03 19.27.52.png
# Resized and cropped image: 7545_color.png
# Resized and cropped image: 7674_color.png
# Resized and cropped image: 7485_color.png
# Resized and cropped image: 截屏2023-06-03 19.28.40.png
# Resized and cropped image: 7315_color.png
# Resized and cropped image: 7223_color.png
# Resized and cropped image: 7077_color.png
# Resized and cropped image: 6336_color.png
# Resized and cropped image: 截屏2023-06-03 19.28.53.png
# Resized and cropped image: 5629_color.png
# Resized and cropped image: 截屏2023-06-03 19.29.02.png
# Resized and cropped image: 4805_color.png
# Resized and cropped image: 3990_color.png
# Resized and cropped image: 3553_color.png
# Resized and cropped image: 1705_color.png
# Resized and cropped image: 1071_color.png
# Resized and cropped image: 965_color.png
# Resized and cropped image: 截屏2023-06-03 19.30.56.png
# Image resizing completed.
